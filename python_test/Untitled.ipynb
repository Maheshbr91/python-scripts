# %%
import os
os.listdir()
# Out:
# ['.ipynb_checkpoints', '095 supermarkets.json', 'data.json', 'Untitled.ipynb']

# %%
import pandas
d=pandas.read_json("095 supermarkets.json")
d
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
d["new id"]=["one","two","three","four","five","six"]
d
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State new id
# 0          CA 94114    one
# 1          CA 94119    two
# 2  California 94114  three
# 3          CA 94114   four
# 4        California   five
# 5          CA 94114    six

# %%
d.loc[1,"new id"]
# Out:
# 'two'

# %%
d.loc[1,"Name"]
# Out:
# 'Bready Shop'

# %%
d.iloc[1,5]
# Out:
# 'Bready Shop'

# %%
d.loc[1:4,"Address":"Name"]
# Out:
#            Address           City Country  Employees  ID         Name
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez

# %%
d.drop("new id",1)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State
# 0          CA 94114
# 1          CA 94119
# 2  California 94114
# 3          CA 94114
# 4        California
# 5          CA 94114

# %%
d.drop[d.index[1:2],0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-b4f8a97d1f8e> in <module>()
# ----> 1 d.drop[d.index[1:2],0]
#
# TypeError: 'method' object is not subscriptable

# %%
d.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %%
d.index[1]
# Out:
# 1

# %%
d.drop(d.index[2],0)
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#         State new id
# 0    CA 94114    one
# 1    CA 94119    two
# 3    CA 94114   four
# 4  California   five
# 5    CA 94114    six

# %%
d.loc[:3,"ID":"new id"]
# Out:
#    ID         Name             State new id
# 0   1      Madeira          CA 94114    one
# 1   2  Bready Shop          CA 94119    two
# 2   3  Super River  California 94114  three
# 3   4   Ben's Shop          CA 94114   four

# %%
d.shape
# Out:
# (6, 8)

# %%
d["newww"]=len(d.index)*["new"]

# %%
d
# Out:
#            Address           City Country  Employees  ID         Name  \
# 0     3666 21st St  San Francisco     USA          8   1      Madeira
# 1   735 Dolores St  San Francisco     USA         15   2  Bready Shop
# 2      332 Hill St  San Francisco     USA         25   3  Super River
# 3     3995 23rd St  San Francisco     USA         10   4   Ben's Shop
# 4  1056 Sanchez St  San Francisco     USA         12   5      Sanchez
# 5  551 Alvarado St  San Francisco     USA         20   6   Richvalley
#
#               State new id newww
# 0          CA 94114    one   new
# 1          CA 94119    two   new
# 2  California 94114  three   new
# 3          CA 94114   four   new
# 4        California   five   new
# 5          CA 94114    six   new

# %%
d.shape[0]
# Out:
# 6

# %%
d.T
# Out:
#                        0               1                 2              3  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Country              USA             USA               USA            USA
# Employees              8              15                25             10
# ID                     1               2                 3              4
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# State           CA 94114        CA 94119  California 94114       CA 94114
# new id               one             two             three           four
# newww                new             new               new            new
#
#                          4                5
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Country                USA              USA
# Employees               12               20
# ...

# %%
d_t=d.T

# %%
d_t["My address]=["my city","country","Emp","ID","Name","State","new
# Out:
#                        0               1                 2              3  \
# Address     3666 21st St  735 Dolores St       332 Hill St   3995 23rd St
# City       San Francisco   San Francisco     San Francisco  San Francisco
# Country              USA             USA               USA            USA
# Employees              8              15                25             10
# ID                     1               2                 3              4
# Name             Madeira     Bready Shop       Super River     Ben's Shop
# State           CA 94114        CA 94119  California 94114       CA 94114
# new id               one             two             three           four
# newww                new             new               new            new
#
#                          4                5
# Address    1056 Sanchez St  551 Alvarado St
# City         San Francisco    San Francisco
# Country                USA              USA
# Employees               12               20
# ...
